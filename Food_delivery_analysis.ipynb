# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('onlinedeliverydata.csv')

# %%
data.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  ...  \
# 0              Post Graduate            4   12.9766    77.5993    560001  ...
# 1                   Graduate            3   12.9770    77.5773    560009  ...
# 2              Post Graduate            3   12.9551    77.6593    560017  ...
# 3                   Graduate            6   12.9473    77.5616    560019  ...
# 4              Post Graduate            4   12.9850    77.5533    560010  ...
#
#      Less Delivery time High Quality of package       Number of calls  \
# 0  Moderately Important    Moderately Important  Moderately Important
# 1        Very Important          Very Important        Very Important
# 2             Important          Very Important  Moderately Important
# 3        Very Important               Important  Moderately Important
# 4             Important               Important  Moderately Important
#
#              Politeness            Freshness            Temperature  \
# 0  Moderately Important  Moderately Important  Moderately Important
# 1        Very Important        Very Important        Very Important
# 2        Very Important        Very Important             Important
# 3        Very Important        Very Important        Very Important
# 4             Important             Important             Important
#
#             Good Taste          Good Quantity Output  \
# 0  Moderately Important  Moderately Important    Yes
# 1        Very Important        Very Important    Yes
# 2        Very Important  Moderately Important    Yes
# 3        Very Important             Important    Yes
# 4        Very Important        Very Important    Yes
#
#                                              Reviews
# 0                                              Nil\n
# 1                                                Nil
# 2  Many a times payment gateways are an issue, so...
# 3                                                nil
# 4                                                NIL
#
# [5 rows x 55 columns]

# %%
data.shape
# Out:
# (388, 55)

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Medium (P1)', 'Medium (P2)', 'Meal(P1)', 'Meal(P2)',
#        'Perference(P1)', 'Perference(P2)', 'Ease and convenient',
#        'Time saving', 'More restaurant choices', 'Easy Payment option',
#        'More Offers and Discount', 'Good Food quality', 'Good Tracking system',
#        'Self Cooking', 'Health Concern', 'Late Delivery', 'Poor Hygiene',
#        'Bad past experience', 'Unavailability', 'Unaffordable',
#        'Long delivery time', 'Delay of delivery person getting assigned',
#        'Delay of delivery person picking up food', 'Wrong order delivered',
#        'Missing item', 'Order placed by mistake', 'Influence of time',
#        'Order Time', 'Maximum wait time', 'Residence in busy location',
#        'Google Maps Accuracy', 'Good Road Condition', 'Low quantity low time',
#        'Delivery person ability', 'Influence of rating', 'Less Delivery time',
#        'High Quality of package', 'Number of calls', 'Politeness',
#        'Freshness ', 'Temperature', 'Good Taste ', 'Good Quantity', 'Output',
#        'Reviews'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',55) #to display full dataframe
data.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#           Medium (P1)   Medium (P2)   Meal(P1) Meal(P2)  \
# 0  Food delivery apps   Web browser  Breakfast    Lunch
# 1  Food delivery apps   Web browser     Snacks   Dinner
# 2  Food delivery apps   Direct call      Lunch   Snacks
# 3  Food delivery apps       Walk-in     Snacks   Dinner
# 4             Walk-in   Direct call      Lunch   Dinner
#
#                            Perference(P1)  \
# 0          Non Veg foods (Lunch / Dinner)
# 1          Non Veg foods (Lunch / Dinner)
# 2          Non Veg foods (Lunch / Dinner)
# 3  Veg foods (Breakfast / Lunch / Dinner)
# 4          Non Veg foods (Lunch / Dinner)
#
#                             Perference(P2) Ease and convenient  \
# 0                    Bakery items (snacks)             Neutral
# 1   Veg foods (Breakfast / Lunch / Dinner)      Strongly agree
# 2                  Ice cream / Cool drinks      Strongly agree
# 3                    Bakery items (snacks)               Agree
# 4   Veg foods (Breakfast / Lunch / Dinner)               Agree
#
#       Time saving More restaurant choices Easy Payment option  \
# 0         Neutral                 Neutral             Neutral
# 1  Strongly agree          Strongly agree      Strongly agree
# 2  Strongly agree          Strongly agree             Neutral
# 3           Agree          Strongly agree               Agree
# 4           Agree                   Agree               Agree
#
#   More Offers and Discount Good Food quality Good Tracking system  \
# 0                  Neutral           Neutral              Neutral
# 1           Strongly agree           Neutral                Agree
# 2                  Neutral          Disagree              Neutral
# 3           Strongly agree             Agree                Agree
# 4                    Agree           Neutral              Neutral
#
#      Self Cooking  Health Concern   Late Delivery    Poor Hygiene  \
# 0         Neutral         Neutral         Neutral         Neutral
# 1  Strongly agree  Strongly agree           Agree  Strongly agree
# 2        Disagree         Neutral         Neutral           Agree
# 3           Agree  Strongly agree         Neutral           Agree
# 4           Agree  Strongly agree  Strongly agree           Agree
#
#   Bad past experience  Unavailability    Unaffordable Long delivery time  \
# 0             Neutral         Neutral         Neutral              Agree
# 1      Strongly agree  Strongly agree  Strongly agree     Strongly agree
# 2               Agree           Agree           Agree              Agree
# 3            Disagree        Disagree         Neutral              Agree
# 4      Strongly agree           Agree        Disagree     Strongly agree
#
#   Delay of delivery person getting assigned  \
# 0                                     Agree
# 1                            Strongly agree
# 2                                     Agree
# 3                                     Agree
# 4                            Strongly agree
#
#   Delay of delivery person picking up food Wrong order delivered  \
# 0                                    Agree                 Agree
# 1                           Strongly agree        Strongly agree
# 2                                    Agree        Strongly agree
# 3                                    Agree              Disagree
# 4                                  Neutral               Neutral
#
#      Missing item Order placed by mistake Influence of time  \
# 0           Agree                   Agree               Yes
# 1  Strongly agree          Strongly agree               Yes
# 2           Agree                 Neutral               Yes
# 3        Disagree                 Neutral               Yes
# 4         Neutral                Disagree               Yes
#
#             Order Time Maximum wait time Residence in busy location  \
# 0  Weekend (Sat & Sun)        30 minutes                      Agree
# 1    Anytime (Mon-Sun)        30 minutes             Strongly Agree
# 2    Anytime (Mon-Sun)        45 minutes                      Agree
# 3    Anytime (Mon-Sun)        30 minutes                   Disagree
# 4  Weekend (Sat & Sun)        30 minutes                      Agree
#
#   Google Maps Accuracy Good Road Condition Low quantity low time  \
# 0              Neutral             Neutral               Neutral
# 1              Neutral            Disagree     Strongly disagree
# 2       Strongly Agree             Neutral               Neutral
# 3                Agree               Agree               Neutral
# 4                Agree               Agree                 Agree
#
#   Delivery person ability Influence of rating    Less Delivery time  \
# 0                 Neutral                 Yes  Moderately Important
# 1                   Agree                 Yes        Very Important
# 2                   Agree                 Yes             Important
# 3                   Agree                 Yes        Very Important
# 4                   Agree                 Yes             Important
#
#   High Quality of package       Number of calls            Politeness  \
# 0    Moderately Important  Moderately Important  Moderately Important
# 1          Very Important        Very Important        Very Important
# 2          Very Important  Moderately Important        Very Important
# 3               Important  Moderately Important        Very Important
# 4               Important  Moderately Important             Important
#
#              Freshness            Temperature           Good Taste   \
# 0  Moderately Important  Moderately Important  Moderately Important
# 1        Very Important        Very Important        Very Important
# 2        Very Important             Important        Very Important
# 3        Very Important        Very Important        Very Important
# 4             Important             Important        Very Important
#
#           Good Quantity Output  \
# 0  Moderately Important    Yes
# 1        Very Important    Yes
# 2  Moderately Important    Yes
# 3             Important    Yes
# 4        Very Important    Yes
#
#                                              Reviews
# 0                                              Nil\n
# 1                                                Nil
# 2  Many a times payment gateways are an issue, so...
# 3                                                nil
# 4                                                NIL

# %%
data.isnull().sum()
# Out:
# Age                                          0
# Gender                                       0
# Marital Status                               0
# Occupation                                   0
# Monthly Income                               0
# Educational Qualifications                   0
# Family size                                  0
# latitude                                     0
# longitude                                    0
# Pin code                                     0
# Medium (P1)                                  0
# Medium (P2)                                  0
# Meal(P1)                                     0
# Meal(P2)                                     0
# Perference(P1)                               0
# Perference(P2)                               0
# Ease and convenient                          0
# Time saving                                  0
# More restaurant choices                      0
# Easy Payment option                          0
# More Offers and Discount                     0
# Good Food quality                            0
# Good Tracking system                         0
# Self Cooking                                 0
# Health Concern                               0
# Late Delivery                                0
# Poor Hygiene                                 0
# Bad past experience                          0
# Unavailability                               0
# Unaffordable                                 0
# Long delivery time                           0
# Delay of delivery person getting assigned    0
# Delay of delivery person picking up food     0
# Wrong order delivered                        0
# Missing item                                 0
# Order placed by mistake                      0
# Influence of time                            0
# Order Time                                   0
# Maximum wait time                            0
# Residence in busy location                   0
# Google Maps Accuracy                         0
# Good Road Condition                          0
# Low quantity low time                        0
# Delivery person ability                      0
# Influence of rating                          0
# Less Delivery time                           0
# High Quality of package                      0
# Number of calls                              0
# Politeness                                   0
# Freshness                                    0
# Temperature                                  0
# Good Taste                                   0
# Good Quantity                                0
# Output                                       0
# Reviews                                      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 55 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Age                                        388 non-null    int64
#  1   Gender                                     388 non-null    object
#  2   Marital Status                             388 non-null    object
#  3   Occupation                                 388 non-null    object
#  4   Monthly Income                             388 non-null    object
#  5   Educational Qualifications                 388 non-null    object
#  6   Family size                                388 non-null    int64
#  7   latitude                                   388 non-null    float64
#  8   longitude                                  388 non-null    float64
#  9   Pin code                                   388 non-null    int64
#  10  Medium (P1)                                388 non-null    object
#  11  Medium (P2)                                388 non-null    object
#  12  Meal(P1)                                   388 non-null    object
#  13  Meal(P2)                                   388 non-null    object
#  14  Perference(P1)                             388 non-null    object
#  15  Perference(P2)                             388 non-null    object
#  16  Ease and convenient                        388 non-null    object
#  17  Time saving                                388 non-null    object
#  18  More restaurant choices                    388 non-null    object
#  19  Easy Payment option                        388 non-null    object
#  20  More Offers and Discount                   388 non-null    object
#  21  Good Food quality                          388 non-null    object
#  22  Good Tracking system                       388 non-null    object
#  23  Self Cooking                               388 non-null    object
#  24  Health Concern                             388 non-null    object
#  25  Late Delivery                              388 non-null    object
#  26  Poor Hygiene                               388 non-null    object
#  27  Bad past experience                        388 non-null    object
#  28  Unavailability                             388 non-null    object
#  29  Unaffordable                               388 non-null    object
#  30  Long delivery time                         388 non-null    object
#  31  Delay of delivery person getting assigned  388 non-null    object
#  32  Delay of delivery person picking up food   388 non-null    object
#  33  Wrong order delivered                      388 non-null    object
#  34  Missing item                               388 non-null    object
#  35  Order placed by mistake                    388 non-null    object
#  36  Influence of time                          388 non-null    object
#  37  Order Time                                 388 non-null    object
#  38  Maximum wait time                          388 non-null    object
#  39  Residence in busy location                 388 non-null    object
#  40  Google Maps Accuracy                       388 non-null    object
#  41  Good Road Condition                        388 non-null    object
#  42  Low quantity low time                      388 non-null    object
#  43  Delivery person ability                    388 non-null    object
#  44  Influence of rating                        388 non-null    object
#  45  Less Delivery time                         388 non-null    object
#  46  High Quality of package                    388 non-null    object
#  47  Number of calls                            388 non-null    object
#  48  Politeness                                 388 non-null    object
#  49  Freshness                                  388 non-null    object
#  50  Temperature                                388 non-null    object
#  51  Good Taste                                 388 non-null    object
#  52  Good Quantity                              388 non-null    object
#  53  Output                                     388 non-null    object
#  54  Reviews                                    388 non-null    object
# dtypes: float64(2), int64(3), object(50)
# memory usage: 166.8+ KB

# %%
data.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   388.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.280928   12.972058   77.600160  560040.113402
# std      2.975593     1.351025    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
#pivot table

# %%
data_pivot = pd.pivot_table(data,index = ['Gender','Marital Status'],values=['Age','Family size'],margins = True)
style = sns.light_palette('red' , as_cmap=True)
piv = data_pivot.style.background_gradient(cmap = style)
piv
# Out:
# <style type="text/css">
# #T_9176a_row0_col0 {
#   background-color: #fd2525;
#   color: #f1f1f1;
# }
# #T_9176a_row0_col1 {
#   background-color: #fd2222;
#   color: #f1f1f1;
# }
# #T_9176a_row1_col0 {
#   background-color: #fa6262;
#   color: #f1f1f1;
# }
# #T_9176a_row1_col1, #T_9176a_row3_col0 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_9176a_row2_col0, #T_9176a_row4_col1 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_9176a_row2_col1 {
#   background-color: #fb4848;
#   color: #f1f1f1;
# }
# #T_9176a_row3_col1 {
#   background-color: #fe0d0d;
#   color: #f1f1f1;
# }
# #T_9176a_row4_col0 {
#   background-color: #fd2424;
#   color: #f1f1f1;
# }
# #T_9176a_row5_col0 {
#   background-color: #f4dfdf;
#   color: #000000;
# }
# #T_9176a_row5_col1 {
#   background-color: #fa6363;
#   color: #f1f1f1;
# }
# #T_9176a_row6_col0 {
#   background-color: #f7a6a6;
#   color: #000000;
# }
# #T_9176a_row6_col1 {
#   background-color: #fb4747;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9176a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9176a_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_9176a_level0_col1" class="col_heading level0 col1" >Family size</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="index_name level1" >Marital Status</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9176a_level0_row0" class="row_heading level0 row0" rowspan="3">Female</th>
#       <th id="T_9176a_level1_row0" class="row_heading level1 row0" >Married</th>
#       <td id="T_9176a_row0_col0" class="data row0 col0" >27.265306</td>
#       <td id="T_9176a_row0_col1" class="data row0 col1" >3.653061</td>
#     </tr>
#     <tr>
#       <th id="T_9176a_level1_row1" class="row_heading level1 row1" >Prefer not to say</th>
#       <td id="T_9176a_row1_col0" class="data row1 col0" >26.000000</td>
#       <td id="T_9176a_row1_col1" class="data row1 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9176a_level1_row2" class="row_heading level1 row2" >Single</th>
#       <td id="T_9176a_row2_col0" class="data row2 col0" >23.098214</td>
#       <td id="T_9176a_row2_col1" class="data row2 col1" >3.276786</td>
#     </tr>
#     <tr>
#       <th id="T_9176a_level0_row3" class="row_heading level0 row3" rowspan="3">Male</th>
#       <th id="T_9176a_level1_row3" class="row_heading level1 row3" >Married</th>
#       <td id="T_9176a_row3_col0" class="data row3 col0" >28.016949</td>
#       <td id="T_9176a_row3_col1" class="data row3 col1" >3.864407</td>
#     </tr>
#     <tr>
#       <th id="T_9176a_level1_row4" class="row_heading level1 row4" >Prefer not to say</th>
#       <td id="T_9176a_row4_col0" class="data row4 col0" >27.285714</td>
#       <td id="T_9176a_row4_col1" class="data row4 col1" >1.571429</td>
#     </tr>
#     <tr>
#       <th id="T_9176a_level1_row5" class="row_heading level1 row5" >Single</th>
#       <td id="T_9176a_row5_col0" class="data row5 col0" >23.455128</td>
#       <td id="T_9176a_row5_col1" class="data row5 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9176a_level0_row6" class="row_heading level0 row6" >All</th>
#       <th id="T_9176a_level1_row6" class="row_heading level1 row6" ></th>
#       <td id="T_9176a_row6_col0" class="data row6 col0" >24.628866</td>
#       <td id="T_9176a_row6_col1" class="data row6 col1" >3.280928</td>
#     </tr>
#   </tbody>
# </table>

# %%
pivot2 = pd.pivot_table(data,index = ['Occupation','Educational Qualifications'],values=['Age','Family size'])

# %%
pivot2.style.bar()
# Out:
# <style type="text/css">
# #T_93dfb_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 82.9%, transparent 82.9%);
# }
# #T_93dfb_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 60.2%, transparent 60.2%);
# }
# #T_93dfb_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.5%, transparent 87.5%);
# }
# #T_93dfb_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.6%, transparent 75.6%);
# }
# #T_93dfb_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 82.0%, transparent 82.0%);
# }
# #T_93dfb_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.0%, transparent 57.0%);
# }
# #T_93dfb_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 99.0%, transparent 99.0%);
# }
# #T_93dfb_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.2%, transparent 80.2%);
# }
# #T_93dfb_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.2%, transparent 91.2%);
# }
# #T_93dfb_row4_col1, #T_93dfb_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_93dfb_row5_col1, #T_93dfb_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 55.6%, transparent 55.6%);
# }
# #T_93dfb_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 83.3%, transparent 83.3%);
# }
# #T_93dfb_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.5%, transparent 71.5%);
# }
# #T_93dfb_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.1%, transparent 77.1%);
# }
# #T_93dfb_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 79.9%, transparent 79.9%);
# }
# #T_93dfb_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 51.6%, transparent 51.6%);
# }
# #T_93dfb_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 84.8%, transparent 84.8%);
# }
# #T_93dfb_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.8%, transparent 68.8%);
# }
# #T_93dfb_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.8%, transparent 93.8%);
# }
# #T_93dfb_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.1%, transparent 74.1%);
# }
# #T_93dfb_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.7%, transparent 68.7%);
# }
# #T_93dfb_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 56.3%, transparent 56.3%);
# }
# #T_93dfb_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.9%, transparent 78.9%);
# }
# #T_93dfb_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.5%, transparent 62.5%);
# }
# #T_93dfb_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 72.4%, transparent 72.4%);
# }
# #T_93dfb_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.5%, transparent 59.5%);
# }
# </style>
# <table id="T_93dfb">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93dfb_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_93dfb_level0_col1" class="col_heading level0 col1" >Family size</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Occupation</th>
#       <th class="index_name level1" >Educational Qualifications</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93dfb_level0_row0" class="row_heading level0 row0" rowspan="3">Employee</th>
#       <th id="T_93dfb_level1_row0" class="row_heading level1 row0" >Graduate</th>
#       <td id="T_93dfb_row0_col0" class="data row0 col0" >26.514706</td>
#       <td id="T_93dfb_row0_col1" class="data row0 col1" >3.250000</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level1_row1" class="row_heading level1 row1" >Ph.D</th>
#       <td id="T_93dfb_row1_col0" class="data row1 col0" >28.000000</td>
#       <td id="T_93dfb_row1_col1" class="data row1 col1" >4.083333</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level1_row2" class="row_heading level1 row2" >Post Graduate</th>
#       <td id="T_93dfb_row2_col0" class="data row2 col0" >26.236842</td>
#       <td id="T_93dfb_row2_col1" class="data row2 col1" >3.078947</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level0_row3" class="row_heading level0 row3" rowspan="3">House wife</th>
#       <th id="T_93dfb_level1_row3" class="row_heading level1 row3" >Graduate</th>
#       <td id="T_93dfb_row3_col0" class="data row3 col0" >31.666667</td>
#       <td id="T_93dfb_row3_col1" class="data row3 col1" >4.333333</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level1_row4" class="row_heading level1 row4" >School</th>
#       <td id="T_93dfb_row4_col0" class="data row4 col0" >29.200000</td>
#       <td id="T_93dfb_row4_col1" class="data row4 col1" >5.400000</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level1_row5" class="row_heading level1 row5" >Uneducated</th>
#       <td id="T_93dfb_row5_col0" class="data row5 col0" >32.000000</td>
#       <td id="T_93dfb_row5_col1" class="data row5 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level0_row6" class="row_heading level0 row6" rowspan="5">Self Employeed</th>
#       <th id="T_93dfb_level1_row6" class="row_heading level1 row6" >Graduate</th>
#       <td id="T_93dfb_row6_col0" class="data row6 col0" >26.655172</td>
#       <td id="T_93dfb_row6_col1" class="data row6 col1" >3.862069</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level1_row7" class="row_heading level1 row7" >Ph.D</th>
#       <td id="T_93dfb_row7_col0" class="data row7 col0" >24.666667</td>
#       <td id="T_93dfb_row7_col1" class="data row7 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level1_row8" class="row_heading level1 row8" >Post Graduate</th>
#       <td id="T_93dfb_row8_col0" class="data row8 col0" >25.571429</td>
#       <td id="T_93dfb_row8_col1" class="data row8 col1" >2.785714</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level1_row9" class="row_heading level1 row9" >School</th>
#       <td id="T_93dfb_row9_col0" class="data row9 col0" >27.142857</td>
#       <td id="T_93dfb_row9_col1" class="data row9 col1" >3.714286</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level1_row10" class="row_heading level1 row10" >Uneducated</th>
#       <td id="T_93dfb_row10_col0" class="data row10 col0" >30.000000</td>
#       <td id="T_93dfb_row10_col1" class="data row10 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level0_row11" class="row_heading level0 row11" rowspan="3">Student</th>
#       <th id="T_93dfb_level1_row11" class="row_heading level1 row11" >Graduate</th>
#       <td id="T_93dfb_row11_col0" class="data row11 col0" >21.987013</td>
#       <td id="T_93dfb_row11_col1" class="data row11 col1" >3.038961</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level1_row12" class="row_heading level1 row12" >Ph.D</th>
#       <td id="T_93dfb_row12_col0" class="data row12 col0" >25.250000</td>
#       <td id="T_93dfb_row12_col1" class="data row12 col1" >3.375000</td>
#     </tr>
#     <tr>
#       <th id="T_93dfb_level1_row13" class="row_heading level1 row13" >Post Graduate</th>
#       <td id="T_93dfb_row13_col0" class="data row13 col0" >23.172131</td>
#       <td id="T_93dfb_row13_col1" class="data row13 col1" >3.213115</td>
#     </tr>
#   </tbody>
# </table>

# %%
data['Monthly Income'].unique()
# Out:
# array(['No Income', 'Below Rs.10000', 'More than 50000', '10001 to 25000',
#        '25001 to 50000'], dtype=object)

# %%
pivot3 = pd.pivot_table(data,index = ['Occupation','Monthly Income'],
                        values=['Age','Family size'],
                        aggfunc=[np.mean,len,np.std])

# %%
pivot3.style.bar()
# Out:
# <style type="text/css">
# #T_de910_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.1%, transparent 80.1%);
# }
# #T_de910_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 64.6%, transparent 64.6%);
# }
# #T_de910_row0_col2, #T_de910_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.9%, transparent 12.9%);
# }
# #T_de910_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.4%, transparent 65.4%);
# }
# #T_de910_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 56.4%, transparent 56.4%);
# }
# #T_de910_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 88.2%, transparent 88.2%);
# }
# #T_de910_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.6%, transparent 65.6%);
# }
# #T_de910_row1_col2, #T_de910_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.2%, transparent 29.2%);
# }
# #T_de910_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.5%, transparent 77.5%);
# }
# #T_de910_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 52.5%, transparent 52.5%);
# }
# #T_de910_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 86.5%, transparent 86.5%);
# }
# #T_de910_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 54.9%, transparent 54.9%);
# }
# #T_de910_row2_col2, #T_de910_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.5%, transparent 4.5%);
# }
# #T_de910_row2_col4, #T_de910_row2_col5, #T_de910_row4_col0, #T_de910_row4_col1, #T_de910_row12_col2, #T_de910_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_de910_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.9%, transparent 91.9%);
# }
# #T_de910_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.9%, transparent 78.9%);
# }
# #T_de910_row3_col2, #T_de910_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.7%, transparent 19.7%);
# }
# #T_de910_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.8%, transparent 89.8%);
# }
# #T_de910_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.1%, transparent 71.1%);
# }
# #T_de910_row4_col2, #T_de910_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.1%, transparent 5.1%);
# }
# #T_de910_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 85.2%, transparent 85.2%);
# }
# #T_de910_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 51.2%, transparent 51.2%);
# }
# #T_de910_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 85.9%, transparent 85.9%);
# }
# #T_de910_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.4%, transparent 68.4%);
# }
# #T_de910_row5_col2, #T_de910_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.4%, transparent 8.4%);
# }
# #T_de910_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.3%, transparent 71.3%);
# }
# #T_de910_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.0%, transparent 65.0%);
# }
# #T_de910_row6_col0, #T_de910_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 85.7%, transparent 85.7%);
# }
# #T_de910_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.7%, transparent 80.7%);
# }
# #T_de910_row6_col2, #T_de910_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.9%, transparent 7.9%);
# }
# #T_de910_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 49.4%, transparent 49.4%);
# }
# #T_de910_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.9%, transparent 65.9%);
# }
# #T_de910_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 88.4%, transparent 88.4%);
# }
# #T_de910_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 72.8%, transparent 72.8%);
# }
# #T_de910_row7_col2, #T_de910_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.0%, transparent 14.0%);
# }
# #T_de910_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 66.9%, transparent 66.9%);
# }
# #T_de910_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.2%, transparent 78.2%);
# }
# #T_de910_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.8%, transparent 74.8%);
# }
# #T_de910_row8_col2, #T_de910_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.9%, transparent 3.9%);
# }
# #T_de910_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 37.2%, transparent 37.2%);
# }
# #T_de910_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 53.1%, transparent 53.1%);
# }
# #T_de910_row9_col0, #T_de910_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.8%, transparent 75.8%);
# }
# #T_de910_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.8%, transparent 48.8%);
# }
# #T_de910_row9_col2, #T_de910_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.7%, transparent 1.7%);
# }
# #T_de910_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.7%, transparent 29.7%);
# }
# #T_de910_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 54.1%, transparent 54.1%);
# }
# #T_de910_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.0%, transparent 75.0%);
# }
# #T_de910_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 64.0%, transparent 64.0%);
# }
# #T_de910_row10_col2, #T_de910_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.6%, transparent 9.6%);
# }
# #T_de910_row10_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.0%, transparent 40.0%);
# }
# #T_de910_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.2%, transparent 48.2%);
# }
# #T_de910_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.8%, transparent 62.8%);
# }
# #T_de910_row11_col2, #T_de910_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.1%, transparent 1.1%);
# }
# #T_de910_row11_col4, #T_de910_row11_col5 {
#   width: 10em;
# }
# #T_de910_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.1%, transparent 75.1%);
# }
# #T_de910_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 66.2%, transparent 66.2%);
# }
# #T_de910_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 47.3%, transparent 47.3%);
# }
# #T_de910_row12_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.4%, transparent 59.4%);
# }
# </style>
# <table id="T_de910">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de910_level0_col0" class="col_heading level0 col0" colspan="2">mean</th>
#       <th id="T_de910_level0_col2" class="col_heading level0 col2" colspan="2">len</th>
#       <th id="T_de910_level0_col4" class="col_heading level0 col4" colspan="2">std</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_de910_level1_col0" class="col_heading level1 col0" >Age</th>
#       <th id="T_de910_level1_col1" class="col_heading level1 col1" >Family size</th>
#       <th id="T_de910_level1_col2" class="col_heading level1 col2" >Age</th>
#       <th id="T_de910_level1_col3" class="col_heading level1 col3" >Family size</th>
#       <th id="T_de910_level1_col4" class="col_heading level1 col4" >Age</th>
#       <th id="T_de910_level1_col5" class="col_heading level1 col5" >Family size</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Occupation</th>
#       <th class="index_name level1" >Monthly Income</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3"

# %%
pivot4 = pd.pivot_table(data,index = ["Order Time","Maximum wait time"],values = ['Age','Family size'],columns = ['Influence of time'],aggfunc={'Influence of time':len},fill_value=0)

# %%
cm = sns.light_palette("blue", as_cmap=True)
pivot4.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_a8f4a_row0_col0, #T_a8f4a_row8_col0 {
#   background-color: #d6d6f4;
#   color: #000000;
# }
# #T_a8f4a_row0_col1, #T_a8f4a_row4_col2, #T_a8f4a_row5_col0, #T_a8f4a_row5_col1, #T_a8f4a_row6_col0, #T_a8f4a_row6_col2, #T_a8f4a_row7_col0, #T_a8f4a_row8_col1, #T_a8f4a_row9_col0, #T_a8f4a_row9_col2, #T_a8f4a_row10_col0, #T_a8f4a_row10_col1, #T_a8f4a_row14_col0, #T_a8f4a_row14_col1 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_a8f4a_row0_col2 {
#   background-color: #a8a8f6;
#   color: #000000;
# }
# #T_a8f4a_row1_col0 {
#   background-color: #1a1afe;
#   color: #f1f1f1;
# }
# #T_a8f4a_row1_col1 {
#   background-color: #8181f8;
#   color: #f1f1f1;
# }
# #T_a8f4a_row1_col2, #T_a8f4a_row2_col0, #T_a8f4a_row3_col1 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_a8f4a_row2_col1 {
#   background-color: #5c5cfa;
#   color: #f1f1f1;
# }
# #T_a8f4a_row2_col2 {
#   background-color: #1313fe;
#   color: #f1f1f1;
# }
# #T_a8f4a_row3_col0 {
#   background-color: #6b6bfa;
#   color: #f1f1f1;
# }
# #T_a8f4a_row3_col2, #T_a8f4a_row5_col2 {
#   background-color: #e9e9f3;
#   color: #000000;
# }
# #T_a8f4a_row4_col0 {
#   background-color: #bcbcf5;
#   color: #000000;
# }
# #T_a8f4a_row4_col1 {
#   background-color: #2525fd;
#   color: #f1f1f1;
# }
# #T_a8f4a_row6_col1, #T_a8f4a_row7_col1, #T_a8f4a_row9_col1 {
#   background-color: #dedff4;
#   color: #000000;
# }
# #T_a8f4a_row7_col2, #T_a8f4a_row14_col2 {
#   background-color: #e6e6f3;
#   color: #000000;
# }
# #T_a8f4a_row8_col2 {
#   background-color: #efeff3;
#   color: #000000;
# }
# #T_a8f4a_row10_col2 {
#   background-color: #e0e0f4;
#   color: #000000;
# }
# #T_a8f4a_row11_col0 {
#   background-color: #a0a0f7;
#   color: #f1f1f1;
# }
# #T_a8f4a_row11_col1 {
#   background-color: #b9b9f6;
#   color: #000000;
# }
# #T_a8f4a_row11_col2 {
#   background-color: #ababf6;
#   color: #000000;
# }
# #T_a8f4a_row12_col0 {
#   background-color: #5050fb;
#   color: #f1f1f1;
# }
# #T_a8f4a_row12_col1, #T_a8f4a_row13_col1 {
#   background-color: #ccccf5;
#   color: #000000;
# }
# #T_a8f4a_row12_col2 {
#   background-color: #8787f8;
#   color: #f1f1f1;
# }
# #T_a8f4a_row13_col0 {
#   background-color: #8686f8;
#   color: #f1f1f1;
# }
# #T_a8f4a_row13_col2 {
#   background-color: #ececf3;
#   color: #000000;
# }
# </style>
# <table id="T_a8f4a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8f4a_level0_col0" class="col_heading level0 col0" colspan="3">Influence of time</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Influence of time</th>
#       <th id="T_a8f4a_level1_col0" class="col_heading level1 col0" >Maybe</th>
#       <th id="T_a8f4a_level1_col1" class="col_heading level1 col1" >No</th>
#       <th id="T_a8f4a_level1_col2" class="col_heading level1 col2" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Order Time</th>
#       <th class="index_name level1" >Maximum wait time</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8f4a_level0_row0" class="row_heading level0 row0" rowspan="5">Anytime (Mon-Sun)</th>
#       <th id="T_a8f4a_level1_row0" class="row_heading level1 row0" >15 minutes</th>
#       <td id="T_a8f4a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a8f4a_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_a8f4a_row0_col2" class="data row0 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row1" class="row_heading level1 row1" >30 minutes</th>
#       <td id="T_a8f4a_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_a8f4a_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_a8f4a_row1_col2" class="data row1 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row2" class="row_heading level1 row2" >45 minutes</th>
#       <td id="T_a8f4a_row2_col0" class="data row2 col0" >9</td>
#       <td id="T_a8f4a_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_a8f4a_row2_col2" class="data row2 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row3" class="row_heading level1 row3" >60 minutes</th>
#       <td id="T_a8f4a_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_a8f4a_row3_col1" class="data row3 col1" >13</td>
#       <td id="T_a8f4a_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row4" class="row_heading level1 row4" >More than 60 minutes</th>
#       <td id="T_a8f4a_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_a8f4a_row4_col1" class="data row4 col1" >11</td>
#       <td id="T_a8f4a_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level0_row5" class="row_heading level0 row5" rowspan="5">Weekdays (Mon-Fri)</th>
#       <th id="T_a8f4a_level1_row5" class="row_heading level1 row5" >15 minutes</th>
#       <td id="T_a8f4a_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_a8f4a_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_a8f4a_row5_col2" class="data row5 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row6" class="row_heading level1 row6" >30 minutes</th>
#       <td id="T_a8f4a_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_a8f4a_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_a8f4a_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row7" class="row_heading level1 row7" >45 minutes</th>
#       <td id="T_a8f4a_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_a8f4a_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_a8f4a_row7_col2" class="data row7 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row8" class="row_heading level1 row8" >60 minutes</th>
#       <td id="T_a8f4a_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_a8f4a_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_a8f4a_row8_col2" class="data row8 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row9" class="row_heading level1 row9" >More than 60 minutes</th>
#       <td id="T_a8f4a_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_a8f4a_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_a8f4a_row9_col2" class="data row9 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level0_row10" class="row_heading level0 row10" rowspan="5">Weekend (Sat & Sun)</th>
#       <th id="T_a8f4a_level1_row10" class="row_heading level1 row10" >15 minutes</th>
#       <td id="T_a8f4a_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_a8f4a_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_a8f4a_row10_col2" class="data row10 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row11" class="row_heading level1 row11" >30 minutes</th>
#       <td id="T_a8f4a_row11_col0" class="data row11 col0" >3</td>
#       <td id="T_a8f4a_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_a8f4a_row11_col2" class="data row11 col2" >27</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row12" class="row_heading level1 row12" >45 minutes</th>
#       <td id="T_a8f4a_row12_col0" class="data row12 col0" >6</td>
#       <td id="T_a8f4a_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_a8f4a_row12_col2" class="data row12 col2" >40</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row13" class="row_heading level1 row13" >60 minutes</th>
#       <td id="T_a8f4a_row13_col0" class="data row13 col0" >4</td>
#       <td id="T_a8f4a_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_a8f4a_row13_col2" class="data row13 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a8f4a_level1_row14" class="row_heading level1 row14" >More than 60 minutes</th>
#       <td id="T_a8f4a_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_a8f4a_row14_col1" class="data row14 col1" >0</td>
#       <td id="T_a8f4a_row14_col2" class="data row14 col2" >5</td>
#     </tr>
#   </tbody>
# </table>

# %%
pivot5 = pd.pivot_table(data,index = ["Medium (P1)","Perference(P1)"],values = ['Age','Family size'],columns = ['Influence of time'],aggfunc={'Influence of time':len},fill_value=0)

# %%
cm = sns.light_palette("blue", as_cmap=True)
pivot5.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_d825a_row0_col0, #T_d825a_row0_col1, #T_d825a_row1_col0, #T_d825a_row1_col1, #T_d825a_row3_col0, #T_d825a_row3_col1, #T_d825a_row5_col1, #T_d825a_row5_col2, #T_d825a_row6_col0, #T_d825a_row7_col0, #T_d825a_row8_col1 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_d825a_row0_col2 {
#   background-color: #ededf3;
#   color: #000000;
# }
# #T_d825a_row1_col2, #T_d825a_row8_col2 {
#   background-color: #efeff3;
#   color: #000000;
# }
# #T_d825a_row2_col0, #T_d825a_row2_col1, #T_d825a_row2_col2 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_d825a_row3_col2 {
#   background-color: #eeeef3;
#   color: #000000;
# }
# #T_d825a_row4_col0 {
#   background-color: #a3a3f7;
#   color: #f1f1f1;
# }
# #T_d825a_row4_col1, #T_d825a_row6_col1 {
#   background-color: #dfdff4;
#   color: #000000;
# }
# #T_d825a_row4_col2 {
#   background-color: #bbbbf5;
#   color: #000000;
# }
# #T_d825a_row5_col0, #T_d825a_row8_col0 {
#   background-color: #e8e8f3;
#   color: #000000;
# }
# #T_d825a_row6_col2 {
#   background-color: #e4e4f3;
#   color: #000000;
# }
# #T_d825a_row7_col1 {
#   background-color: #ebebf3;
#   color: #000000;
# }
# #T_d825a_row7_col2 {
#   background-color: #ececf3;
#   color: #000000;
# }
# </style>
# <table id="T_d825a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d825a_level0_col0" class="col_heading level0 col0" colspan="3">Influence of time</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Influence of time</th>
#       <th id="T_d825a_level1_col0" class="col_heading level1 col0" >Maybe</th>
#       <th id="T_d825a_level1_col1" class="col_heading level1 col1" >No</th>
#       <th id="T_d825a_level1_col2" class="col_heading level1 col2" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Medium (P1)</th>
#       <th class="index_name level1" >Perference(P1)</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d825a_level0_row0" class="row_heading level0 row0" rowspan="2">Direct call</th>
#       <th id="T_d825a_level1_row0" class="row_heading level1 row0" >Non Veg foods (Lunch / Dinner)</th>
#       <td id="T_d825a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d825a_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_d825a_row0_col2" class="data row0 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d825a_level1_row1" class="row_heading level1 row1" >Veg foods (Breakfast / Lunch / Dinner)</th>
#       <td id="T_d825a_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_d825a_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_d825a_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d825a_level0_row2" class="row_heading level0 row2" rowspan="3">Food delivery apps</th>
#       <th id="T_d825a_level1_row2" class="row_heading level1 row2" >Non Veg foods (Lunch / Dinner)</th>
#       <td id="T_d825a_row2_col0" class="data row2 col0" >28</td>
#       <td id="T_d825a_row2_col1" class="data row2 col1" >41</td>
#       <td id="T_d825a_row2_col2" class="data row2 col2" >224</td>
#     </tr>
#     <tr>
#       <th id="T_d825a_level1_row3" class="row_heading level1 row3" >Sweets</th>
#       <td id="T_d825a_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_d825a_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_d825a_row3_col2" class="data row3 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d825a_level1_row4" class="row_heading level1 row4" >Veg foods (Breakfast / Lunch / Dinner)</th>
#       <td id="T_d825a_row4_col0" class="data row4 col0" >9</td>
#       <td id="T_d825a_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_d825a_row4_col2" class="data row4 col2" >50</td>
#     </tr>
#     <tr>
#       <th id="T_d825a_level0_row5" class="row_heading level0 row5" rowspan="3">Walk-in</th>
#       <th id="T_d825a_level1_row5" class="row_heading level1 row5" >Bakery items (snacks)</th>
#       <td id="T_d825a_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_d825a_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_d825a_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d825a_level1_row6" class="row_heading level1 row6" >Non Veg foods (Lunch / Dinner)</th>
#       <td id="T_d825a_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_d825a_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_d825a_row6_col2" class="data row6 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_d825a_level1_row7" class="row_heading level1 row7" >Veg foods (Breakfast / Lunch / Dinner)</th>
#       <td id="T_d825a_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_d825a_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_d825a_row7_col2" class="data row7 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d825a_level0_row8" class="row_heading level0 row8" >Web browser</th>
#       <th id="T_d825a_level1_row8" class="row_heading level1 row8" >Non Veg foods (Lunch / Dinner)</th>
#       <td id="T_d825a_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_d825a_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_d825a_row8_col2" class="data row8 col2" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### EDA

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Medium (P1)', 'Medium (P2)', 'Meal(P1)', 'Meal(P2)',
#        'Perference(P1)', 'Perference(P2)', 'Ease and convenient',
#        'Time saving', 'More restaurant choices', 'Easy Payment option',
#        'More Offers and Discount', 'Good Food quality', 'Good Tracking system',
#        'Self Cooking', 'Health Concern', 'Late Delivery', 'Poor Hygiene',
#        'Bad past experience', 'Unavailability', 'Unaffordable',
#        'Long delivery time', 'Delay of delivery person getting assigned',
#        'Delay of delivery person picking up food', 'Wrong order delivered',
#        'Missing item', 'Order placed by mistake', 'Influence of time',
#        'Order Time', 'Maximum wait time', 'Residence in busy location',
#        'Google Maps Accuracy', 'Good Road Condition', 'Low quantity low time',
#        'Delivery person ability', 'Influence of rating', 'Less Delivery time',
#        'High Quality of package', 'Number of calls', 'Politeness',
#        'Freshness ', 'Temperature', 'Good Taste ', 'Good Quantity', 'Output',
#        'Reviews'],
#       dtype='object')

# %%
#Setting up the frame 
fig,axes = plt.subplots(nrows=2,ncols=2,dpi=120,figsize = (8,6))

#Distribution of age with distplot
plot00=sns.distplot(data['Age'],ax=axes[0][0],color='green')
axes[0][0].yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
axes[0][0].set_title('Distribution of Age',fontdict={'fontsize':8})
axes[0][0].set_xlabel('Age',fontdict={'fontsize':7})
axes[0][0].set_ylabel('Count/Dist.',fontdict={'fontsize':7})
plt.tight_layout()

#distribution of family size with distplot
plot01=sns.distplot(data['Family size'],ax=axes[0][1],color='red')
axes[0][1].yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
axes[0][1].set_title('Distribution of Family Size',fontdict={'fontsize':8})
axes[0][1].set_xlabel('Size of family',fontdict = {'fontsize':7})
axes[0][1].set_ylabel('Count/Dist.',fontdict={'fontsize':7})
plt.tight_layout()

#Age-Boxplot
plot10=sns.boxplot(data['Age'],ax=axes[1][0])
axes[1][0].set_title('Age Distribution',fontdict={'fontsize':8})
axes[1][0].set_xlabel('Distribution',fontdict={'fontsize':7})
axes[1][0].set_ylabel(r'Age',fontdict={'fontsize':7})
plt.tight_layout()

#FamilySize-Boxplot
plot11=sns.boxplot(data['Family size'],ax=axes[1][1])
axes[1][1].set_title(r'Numerical Summary (Family Size)',fontdict={'fontsize':8})
axes[1][1].set_ylabel(r'Size of Family',fontdict={'fontsize':7})
axes[1][1].set_xlabel('Family Size',fontdict={'fontsize':7})
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Demographic Analysis

# %%
#Setting up the frame
plt.figure(figsize = (15, 7))
plt.style.use('seaborn-white')

#Gender Countplot
plt.subplot(2,3,1)
ax = sns.countplot(x="Gender", data=data,
                   facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("dark", 3))
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11)
ax.set_title('Gender count',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count_Gender', fontsize = 12)
plt.tight_layout()

#Marital Status Countplot
plt.subplot(2,3,2)
ax = sns.countplot(x="Marital Status", data=data,
                   facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("dark", 3))
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11)
ax.set_title('Marital Status count',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count_Marital', fontsize = 12)
plt.tight_layout()

#Occupation Countplot
plt.subplot(2,3,3)
ax = sns.countplot(x="Occupation", data=data,
                   facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("dark", 3))
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11)
ax.set_title('Occupation count',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count_Occupation', fontsize = 12)
plt.tight_layout()

#Education Countplot
plt.subplot(2,3,4)
ax = sns.countplot(x="Educational Qualifications", data=data,
                   facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("dark", 3))
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11)
ax.set_title('Educational Qualifications count',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count_Ed', fontsize = 12)
plt.tight_layout()

#Income Countplot
plt.subplot(2,3,5)
ax = sns.countplot(x="Monthly Income", data=data,
                   facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("dark", 3))
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=20)
ax.set_title('Monthly Income count',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count_Income', fontsize = 12)
plt.tight_layout()

#Family Size Countplot
plt.subplot(2,3,6)
ax = sns.countplot(x="Family size", data=data,
                   facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("dark", 3))
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=20)
ax.set_title('Family size',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count_Size', fontsize = 12)
plt.tight_layout()

# %% [markdown]
# ### Consumer preference

# %%
#Setting up the frame
plt.figure(figsize = (15, 7))
plt.style.use('seaborn-white')

#Meal Countplot
plt.subplot(1,3,1)
ax = sns.countplot(x="Meal(P1)", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11)
ax.set_title('Meal count',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count_Meal', fontsize = 12)
plt.tight_layout()

#Medium Countplot
plt.subplot(1,3,2)
ax = sns.countplot(x="Medium (P1)", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11)
ax.set_title('Medium Status count',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count_Medium', fontsize = 12)
plt.tight_layout()

#Preference Countplot
plt.subplot(1,3,3)
ax = sns.countplot(x="Perference(P1)", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=20)
ax.set_title('Preference count',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count_Preference', fontsize = 12)
plt.tight_layout()

# %% [markdown]
# ### Demand of purchurse

# %%
#Setting up the frame
plt.figure(figsize = (15, 7))
plt.style.use('ggplot')

#Ease and convenient Countplot
plt.subplot(2,4,1)
ax = sns.countplot(x="Ease and convenient", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Ease and convenient',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Time Countplot
plt.subplot(2,4,2)
ax = sns.countplot(x="Time saving", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Time saving',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Restaurant Countplot
plt.subplot(2,4,3)
ax = sns.countplot(x="More restaurant choices", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('More restaurant choices',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Payment Countplot
plt.subplot(2,4,4)
ax = sns.countplot(x="Easy Payment option", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Easy Payment option',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Offers Countplot
plt.subplot(2,4,5)
ax = sns.countplot(x="More Offers and Discount", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('More Offers and Discount',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Preference Countplot
plt.subplot(2,4,6)
ax = sns.countplot(x="Good Food quality", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Good Food quality',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count_Preference', fontsize = 12)
plt.tight_layout()

#Tracking Countplot
plt.subplot(2,4,7)
ax = sns.countplot(x="Good Tracking system", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Good Tracking system',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

# %% [markdown]
# ### Restriction in order demand

# %%
#Setting up the frame
plt.figure(figsize = (15, 7))
plt.style.use('seaborn-dark')

#Self cooking Countplot
plt.subplot(2,4,1)
ax = sns.countplot(x="Self Cooking", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Self Cooking',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Health Countplot
plt.subplot(2,4,2)
ax = sns.countplot(x="Health Concern", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Health Concern',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Late delivery Countplot
plt.subplot(2,4,3)
ax = sns.countplot(x="Late Delivery", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Late data',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Hygiene Countplot
plt.subplot(2,4,4)
ax = sns.countplot(x="Poor Hygiene", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Poor Hygiene',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Past Countplot
plt.subplot(2,4,5)
ax = sns.countplot(x="Bad past experience", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Bad past experience',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Unavailability Countplot
plt.subplot(2,4,6)
ax = sns.countplot(x="Unavailability", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Unavailability',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count_Preference', fontsize = 12)
plt.tight_layout()

#Unaffordable Countplot
plt.subplot(2,4,7)
ax = sns.countplot(x="Unaffordable", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Unaffordable',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

# %% [markdown]
# ### Influence in Cancellation of order

# %%
#Setting up the frame
plt.figure(figsize = (15, 7))
plt.style.use('fivethirtyeight')


#Long delivery time Countplot
plt.subplot(2,3,1)
ax = sns.countplot(x="Long delivery time", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Long delivery time',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Delay of delivery person getting assigned Countplot
plt.subplot(2,3,2)
ax = sns.countplot(x="Delay of delivery person getting assigned", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Delay of delivery person getting assigned',fontsize = 15)
ax.set_xlabel('Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Delay of delivery person picking up food Countplot
plt.subplot(2,3,3)
ax = sns.countplot(x="Delay of delivery person picking up food", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Delay of delivery person picking up food',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Wrong order delivered Countplot
plt.subplot(2,3,4)
ax = sns.countplot(x="Wrong order delivered", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Wrong order delivered',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Missing item Countplot
plt.subplot(2,3,5)
ax = sns.countplot(x="Missing item", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Missing item',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count', fontsize = 12)
plt.tight_layout()

#Order placed by mistake Countplot
plt.subplot(2,3,6)
ax = sns.countplot(x="Order placed by mistake", data=data)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=11,rotation=40)
ax.set_title('Order placed by mistake',fontsize = 15)
ax.set_xlabel( 'Types',fontsize = 12) 
ax.set_ylabel('Count_Preference', fontsize = 12)
plt.tight_layout()
